# %%
# Import necessary libraries

import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import time
import os
import spacy
import nltk
import ollama
from difflib import SequenceMatcher

# Setup nltk to create manageable sections of longer blocks of text

nltk.download("punkt")
ner_model = spacy.load("output/model-best")
if not ner_model.has_pipe("sentencizer"):
    ner_model.add_pipe("sentencizer", first=True)
    
    
# Load my S&P 500 company data with CIKs and tickers
sp500_df = pd.read_csv("sp500_with_cik_cleaned.csv")
sp500_df['CIK'] = sp500_df['CIK'].astype(str).str.zfill(10)

HEADERS = {"User-Agent": "Your Name your.email@example.com"}

# Initiate dictionary to store my duplicate entry prevention
extracted_products = {}

# Check for duplicate product names
def is_duplicate(name, company, threshold=0.88):
    existing = extracted_products.get(company, [])
    for prev in existing:
        ratio = SequenceMatcher(None, name.lower(), prev.lower()).ratio()
        if ratio >= threshold:
            return True
    return False

# Logs results
def log(msg):
    print(f"\033[96m[LOG]\033[0m {msg}")

# Retrieves the most recen 8-K filings using the url available from Edgar
def get_most_recent_8k_index_url(cik):
    url = f"https://data.sec.gov/submissions/CIK{cik}.json"
    res = requests.get(url, headers=HEADERS)
    if res.status_code == 200:
        data = res.json()
        for i, form in enumerate(data['filings']['recent']['form']):
            if form == "8-K":
                acc = data['filings']['recent']['accessionNumber'][i]
                acc_no_dash = acc.replace("-", "")
                return f"https://www.sec.gov/Archives/edgar/data/{int(cik)}/{acc_no_dash}/{acc}-index.htm"
    return None

# Extracts Ex. 99.1 url from the 8-K index page
def extract_ex99_url(index_url):
    res = requests.get(index_url, headers=HEADERS)
    soup = BeautifulSoup(res.text, "html.parser")
    for row in soup.find_all("tr"):
        cols = row.find_all("td")
        if len(cols) >= 4 and "EX-99.1" in cols[3].text.upper():
            href = cols[2].find("a", href=True)
            if href:
                return f"https://www.sec.gov{href['href']}" if href['href'].startswith("/") else href['href']
    return None

# Gets the text that is within the url
def fetch_text_from_url(url):
    try:
        res = requests.get(url, headers=HEADERS)
        if res.ok:
            soup = BeautifulSoup(res.text, "html.parser")
            return soup.get_text(separator=" ", strip=True)
    except:
        return ""
    return ""

# backup for if EX-99.1 is missing I can get other HTML pages
def fallback_text_from_index(index_url):
    res = requests.get(index_url, headers=HEADERS)
    soup = BeautifulSoup(res.text, "html.parser")
    for link in soup.find_all("a", href=True):
        href = link['href']
        if href.endswith(".htm") or href.endswith(".html"):
            full_url = f"https://www.sec.gov{href}" if href.startswith("/") else href
            try:
                page = requests.get(full_url, headers=HEADERS)
                text = BeautifulSoup(page.text, "html.parser").get_text(separator=" ", strip=True)
                if any(kw in text.lower() for kw in ["launch", "introduce", "announce", "unveil", "expand"]):
                    return text
            except:
                continue
    return ""

# Retrieve the filing date from the index page
def get_filing_date(index_url):
    try:
        res = requests.get(index_url, headers=HEADERS)
        soup = BeautifulSoup(res.text, "html.parser")
        match = re.search(r"Filing Date\s+(\d{4}-\d{2}-\d{2})", soup.get_text())
        return match.group(1) if match else "N/A"
    except:
        return "N/A"

# Get the product name and description from the text and use trigger words and validation via Ollama's prompt
def extract_product_info(text, company_name, ticker):
    doc = ner_model(text)
    trigger_words = ["launch", "introduce", "unveil", "announce", "expand", "roll out", "release"]
    
    sentences = [
        sent.text.strip() for sent in doc.sents
        if any(w in sent.text.lower() for w in trigger_words)
        and 20 < len(sent.text) < 300
    ]
    log(f"🧠 {len(sentences)} candidate sentences found")

    for sentence in sentences:
        log(f"[CANDIDATE] {sentence}")
        sent_doc = ner_model(sentence)
        for ent in sent_doc.ents:
            if ent.label_ != "PRODUCT":
                continue
            product = ent.text.strip()
            if is_duplicate(product, company_name):
                log(f"⏩ Skipping duplicate: {product}")
                continue

            # Validation via LLM
            validation_prompt = f"""
Is "{product}" a product, service, or platform introduced by {company_name} in the following sentence?

"{sentence}"

Only respond with Yes or No.
""".strip()
            try:
                val_resp = ollama.chat(model="llama3.2:1b", messages=[{"role": "user", "content": validation_prompt}])
                if "yes" not in val_resp["message"]["content"].lower():
                    log(f"❌ LLM Rejected: {product}")
                    continue
            except Exception as e:
                log(f"LLM validation error: {e}")
                continue

            # Description
            description_prompt = f"""
Write a one-sentence product description (under 180 characters):

Company: {company_name}
Product: {product}
Context: {sentence}

Only provide the description text.
""".strip()
            try:
                desc_resp = ollama.chat(model="llama3.2:1b", messages=[{"role": "user", "content": description_prompt}])
                description = desc_resp["message"]["content"].strip()[:180]
                extracted_products.setdefault(company_name, []).append(product)
                return product, description
            except:
                return product, "N/A"

    # Fallback if no NER product
    for sentence in sentences:
        match = re.search(r"(?:launched|introduced|unveiled|released|announced) (the )?([A-Z][a-zA-Z0-9\- ]{3,50})", sentence)
        if match:
            product = match.group(2).strip()
            if is_duplicate(product, company_name):
                continue

            fallback_prompt = f"""
Is "{product}" a product, service, or platform introduced by {company_name} in this sentence?

Sentence: "{sentence}"

Only answer Yes or No.
""".strip()
            try:
                val_resp = ollama.chat(model="llama3.2:1b", messages=[{"role": "user", "content": fallback_prompt}])
                if "yes" in val_resp["message"]["content"].lower():
                    description_prompt = f"""
Write a short description (under 180 characters) of the product mentioned below.

Company: {company_name}
Product: {product}
Context: {sentence}
""".strip()
                    desc_resp = ollama.chat(model="llama3.2:1b", messages=[{"role": "user", "content": description_prompt}])
                    description = desc_resp["message"]["content"].strip()[:180]
                    extracted_products.setdefault(company_name, []).append(product)
                    return product, description
            except:
                continue

    return "N/A", "N/A"

# Save the results in a csv file
def save_to_csv_if_valid(data, filename="extracted_data.csv"):
    if not data["Product Name"] or data["Product Name"].upper() == "N/A":
        log("Skipping invalid product.")
        return
    if os.path.exists(filename):
        df = pd.read_csv(filename)
        df = pd.concat([df, pd.DataFrame([data])], ignore_index=True)
    else:
        df = pd.DataFrame([data])
    df.to_csv(filename, index=False)
    print(f"💾 Saved: {data['Product Name']} → {filename}")

    
# run a pipeline to automate the entire process
def run_full_pipeline():
    for _, row in sp500_df.iterrows():
        cik, company, ticker = row['CIK'], row['Company Name'], row['Ticker']
        print(f"\n📄 Processing {company} ({ticker})")
        index_url = get_most_recent_8k_index_url(cik)
        if not index_url:
            log("No recent 8-K")
            continue

        ex99_url = extract_ex99_url(index_url)
        log(f"EX-99.1: {ex99_url if ex99_url else 'Fallback'}")

        text = fetch_text_from_url(ex99_url) if ex99_url else fallback_text_from_index(index_url)
        if not text:
            log("No usable text")
            continue

        product, description = extract_product_info(text, company, ticker)
        filing_date = get_filing_date(index_url)

        result = {
            "Company Name": company,
            "Ticker Symbol": ticker,
            "Filing Date": filing_date,
            "Product Name": product,
            "Product Description": description
        }

        print("📊 Extracted Result:")
        for k, v in result.items():
            print(f"{k}: {v}")

        save_to_csv_if_valid(result)
        time.sleep(1.2)

# Run the pipeline
run_full_pipeline()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/kylaemmitt/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 📄 Processing 3M (MMM)
# [LOG] EX-99.1: Fallback
# [LOG] 🧠 1 candidate sentences found
# [LOG] [CANDIDATE] Upon
# the authorization by you of the release of the Securities, the several Underwriters propose to offer the Securities for sale upon the
# terms and conditions set forth in the Pricing Prospectus and the Prospectus.
# 📊 Extracted Result:
# Company Name: 3M
# Ticker Symbol: MMM
# Filing Date: 2025-03-13
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing A. O. Smith (AOS)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/91142/000009114225000002/a12312024exhibit991.htm
# [LOG] 🧠 3 candidate sentences found
# [LOG] [CANDIDATE] Reconciliations from GAAP measures to non-GAAP measures are provided in the financial information included in this news release.
# [LOG] [CANDIDATE] Forward-looking Statements This release contains statements that the Company believes are “forward-looking statements” within the meaning of the Private Securities Litigation Reform Act of 1995.
# [LOG] [CANDIDATE] All forward-looking statements are subject to risks and uncertainties that could cause actual results to differ materially from those anticipated as of the date of this release.
# 📊 Extracted Result:
# Company Name: A. O. Smith
# Ticker Symbol: AOS
# Filing Date: 2025-01-30
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing Abbott Laboratories (ABT)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/1800/000162828025002092/abt-2024q4xexhibitx991.htm
# [LOG] 🧠 3 candidate sentences found
# [LOG] [CANDIDATE] During 2024, Abbott announced more than 15 new growth opportunities coming from the company's highly productive R&D pipeline.
# [LOG] [CANDIDATE] more -- Page 7 of 20 — Private Securities Litigation Reform Act of 1995 — A Caution Concerning Forward-Looking Statements Some statements in this news release may be forward-looking statements for purposes of the Private Securities Litigation Reform Act of 1995.
# [LOG] [CANDIDATE] Abbott undertakes no obligation to release publicly any revisions to forward-looking statements as a result of subsequent events or developments, except as required by law.
# 📊 Extracted Result:
# Company Name: Abbott Laboratories
# Ticker Symbol: ABT
# Filing Date: 2025-01-22
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing AbbVie (ABBV)
# [LOG] EX-99.1: Fallback
# [LOG] No usable text
#
# 📄 Processing Accenture (ACN)
# [LOG] EX-99.1: Fallback
# [LOG] No usable text
#
# 📄 Processing Adobe Inc. (ADBE)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/796343/000079634325000052/adbeex991q125.htm
# [LOG] 🧠 3 candidate sentences found
# [LOG] [CANDIDATE] Each of the forward-looking statements we make in this press release involves risks, uncertainties and assumptions based on information available to us as of the date of this press release.
# [LOG] [CANDIDATE] Undue reliance should not be placed on the financial information set forth in this press release, which reflects estimates based on information available at this time.
# [LOG] [CANDIDATE] A reconciliation between GAAP and non-GAAP earnings results and financial targets and a statement regarding use of non-GAAP financial information are provided at the end of this press release and on Adobe’s investor relations website.
# 📊 Extracted Result:
# Company Name: Adobe Inc.
# Ticker Symbol: ADBE
# Filing Date: 2025-03-12
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing Advanced Micro Devices (AMD)
# [LOG] EX-99.1: Fallback
# [LOG] 🧠 4 candidate sentences found
# [LOG] [CANDIDATE] By accepting a Security, each Holder shall waive and release all such liability.
# [LOG] [CANDIDATE] This waiver and release shall be part of the consideration for the issuance of the Securities.
# [LOG] [CANDIDATE] By accepting a Security, each Holder shall waive and release all such liability.
# [LOG] [CANDIDATE] This waiver and release shall be part of the consideration for the issuance of the Securities.
# 📊 Extracted Result:
# Company Name: Advanced Micro Devices
# Ticker Symbol: AMD
# Filing Date: 2025-03-24
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing AES Corporation (AES)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/874761/000119312525058980/d905393dex991.htm
# [LOG] 🧠 2 candidate sentences found
# [LOG] [CANDIDATE] Capitalized terms used in this press release but not otherwise defined herein have the meanings assigned to them in the Offer Documents.
# [LOG] [CANDIDATE] Safe Harbor Disclosure This news release contains
# forward-looking statements within the meaning of the Securities Act of 1933 and of the Securities Exchange Act of 1934.
# 📊 Extracted Result:
# Company Name: AES Corporation
# Ticker Symbol: AES
# Filing Date: 2025-03-20
# Product Name: Safe Harbor
# Product Description: AES Corporation's Safe Harbor provides investors with information on the disclosure requirements related to certain transactions, allowing for transparency and certainty in corpora
# 💾 Saved: Safe Harbor → extracted_data.csv
#
# 📄 Processing Aflac (AFL)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/4977/000000497725000006/aflex991-q42024.htm
# [LOG] 🧠 1 candidate sentences found
# [LOG] [CANDIDATE] The company defines the non-U.S. GAAP financial measures included in this earnings release as follows: • Adjusted earnings are adjusted revenues less benefits and adjusted expenses.
# 📊 Extracted Result:
# Company Name: Aflac
# Ticker Symbol: AFL
# Filing Date: 2025-02-05
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing Agilent Technologies (A)
# [LOG] EX-99.1: Fallback
# [LOG] No usable text
#
# 📄 Processing Air Products (APD)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/2969/000119312525033509/d830166dex991.htm
# [LOG] 🧠 3 candidate sentences found
# [LOG] [CANDIDATE] Additional information, including revisions to the Company’s capital expenditures forecast for fiscal 2025, will be provided in Air Products’ fiscal second quarter earnings release.
# [LOG] [CANDIDATE] This release contains
# “forward-looking statements” within the safe harbor provisions of the Private Securities Litigation Reform Act of 1995.
# [LOG] [CANDIDATE] These forward-looking statements are based on management’s expectations and assumptions as of the date of
# this release and are not guarantees of future performance.
# 📊 Extracted Result:
# Company Name: Air Products
# Ticker Symbol: APD
# Filing Date: 2025-02-24
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing Airbnb (ABNB)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/1559720/000119312525026054/d915198dex991.htm
# [LOG] 🧠 18 candidate sentences found
# [LOG] [CANDIDATE] Today, our service is better than ever, and our platform is ready to
# support the new offerings we’ll launch as part of our May 2025 Summer Release.
# [LOG] ❌ LLM Rejected: 2025 Summer
# [LOG] [CANDIDATE] We’re continuing to build on this momentum in
# 2025, executing a multi-year strategy to perfect the core service, accelerate growth in global markets, and launch and scale new offerings.
# [LOG] [CANDIDATE] Results from our 2024 Winter Release Hosting on Airbnb is one of the best ways to make money from your home, but not everyone has the time to do it.
# [LOG] ❌ LLM Rejected: Winter Release
# [LOG] [CANDIDATE] That’s why we introduced Co-Host Network,3 an easy way to find the best local co-hosts to help manage your Airbnb.
# [LOG] [CANDIDATE] In the four months since launching, Co-Host Network has grown to support almost 100,000 listings.
# [LOG] [CANDIDATE] These listings
# earn approximately twice as much as Airbnb listings in comparable countries.4 We launched Co-Host Network in 10 countries, and are expanding it to Japan and Korea in the coming months.
# [LOG] [CANDIDATE] Recent initiatives include enhanced search functionality, better merchandising, flexible payment options, and the
# launch of local payment methods in nearly two dozen countries, including Brazil, Korea, and Indonesia.
# [LOG] [CANDIDATE] We introduced brand-new listing management tools, making it easier for hosts to list and manage their homes, while giving them the ability to offer more services in the future.
# [LOG] [CANDIDATE] With this new tech platform, we can innovate faster
# and expand beyond short-term rentals into an extensible platform with a range of new offerings.
# [LOG] [CANDIDATE] 7 Localizing the message We reintroduced the brand to Japan with an integrated campaign featuring the line, “All types of
# accommodations, all flavors of Japan.”
# [LOG] [CANDIDATE] During the second half of 2024, we introduced brand campaigns more broadly in Latin America, helping to raise awareness and
# showcase the unique offerings on Airbnb.
# [LOG] [CANDIDATE] We also successfully introduced a local payment method, Pix, in Brazil which led to an uplift in bookings and first-time bookers.
# [LOG] [CANDIDATE] As we expand globally, we will continue to
# prioritize product localization to address the needs of each country. •
# [LOG] [CANDIDATE] For instance, to make it even easier, we introduced Co-Host Network last year.
# [LOG] [CANDIDATE] Since we launched our updated hosting quality system in 2023, we’ve removed over 400,000 listings, and have seen a reduction in customer service issue rates and credit card
# chargeback rates, while guest net promoter scores have improved.
# [LOG] [CANDIDATE] Our strategy to deliver industry-leading growth remains: improving our core business, accelerating growth in global markets, and launching and scaling new offerings beginning with our Summer Release.
# [LOG] [CANDIDATE] Specifically, we plan to invest $200 million to $250 million towards launching and scaling new businesses to be introduced later this year.
# [LOG] [CANDIDATE] The impact of these investments on our quarterly Adjusted
# EBITDA Margin will be the most pronounced during the first nine months of 2025 due to the timing of when we introduce these new offerings.
# 📊 Extracted Result:
# Company Name: Airbnb
# Ticker Symbol: ABNB
# Filing Date: 2025-02-13
# Product Name: Co-Host Network
# Product Description: Airbnb's Co-Host Network connects you with trusted local hosts for property management and guest services.
# 💾 Saved: Co-Host Network → extracted_data.csv
#
# 📄 Processing Akamai Technologies (AKAM)
# [LOG] EX-99.1: Fallback
# [LOG] No usable text
#
# 📄 Processing Albemarle Corporation (ALB)
# [LOG] EX-99.1: Fallback
# [LOG] 🧠 23 candidate sentences found
# [LOG] [CANDIDATE] Greenbushes’ forward-looking exploration strategy focuses on increasing the geological  confidence within the footprint of the tenement holdings to expand the current resource base.
# [LOG] [CANDIDATE] ▪ Water: Complete and execute the design to expand water storage and distribution, including the Salt  Water Gully Dam expansion.
# [LOG] ❌ LLM Rejected: ▪
# [LOG] [CANDIDATE] This capacity will expand to 8.95 Mtpa  upon the construction of a CGP3 plant in 2025.
# [LOG] [CANDIDATE] However,  upon completion of the commissioning of the third chemical-grade plant, this is forecast to expand to a  capacity of 1.8 Mt of concentrate over the next three years.
# [LOG] [CANDIDATE] ▪ Vultan Mines pioneered sluicing operations of the weathered tin oxides between 1935 and 1943 following  which ‘modern’ earthmoving equipment was introduced between 1945 and 1956 to support tin dredging.
# [LOG] ❌ LLM Rejected: Vultan Mines
# [LOG] [CANDIDATE] Significant testing  was only conducted when the comminution circuit for CGP2 was introduced, a design largely retained in CGP3  with minimal additional testing.
# [LOG] [CANDIDATE] # Effective date refers to the date of the Statement (depletion) not the public release date  There are no material differences between 30 June 2023 and the Mineral Resources reported in the TSR in  2024; however, there is a slightly higher tonnage and grade for Inferred.
# [LOG] [CANDIDATE] The 98% grade factor accounts for dilution  introduced during mining across all ore blocks.
# [LOG] [CANDIDATE] # Effective date refers to the date of the Statement (depletion) not the public release date  As noted in Table 12-8, there are only minor variations in quantities between the reporting of the 2023 and  2024 Mineral Reserves.
# [LOG] ❌ LLM Rejected: Mineral Reserves
# [LOG] [CANDIDATE] ▪ Mine through (remove) the sheared pegmatite contact zone running along the C1 Pit Footwall, by  expanding the east wall an additional 10 m; and,  ▪ Implementation of Trigger Action Response Plans (TARP) for radar monitoring and rainfall.
# [LOG] ❌ LLM Rejected: Trigger Action
# [LOG] [CANDIDATE] Current groundwater inflow is under 10 L/s,  though additional refinement of inflow estimates will be needed as the operational pit shell expands.
# [LOG] [CANDIDATE] However, as mining expands into new areas within the lease, this focus  may shift to the industry standard of Li2O recovery.
# [LOG] [CANDIDATE] Waste rock facilities continue to expand supporting ongoing mining operations.
# [LOG] [CANDIDATE] Additionally, the new site camp, completed in January 2024, accommodates a larger workforce,  addressing staffing needs associated with expanded mining and processing activities.
# [LOG] [CANDIDATE] Accounting for 40.1% in 2016,  battery demand has expanded at 36.6% compound average growth rate (CAGR) each year between 2016  and 2023 and is now responsible for 85.0% of all lithium consumed.
# [LOG] [CANDIDATE] Alongside car-buyers’ growing preferences for EVs, looming bans on pure-ICE and then hybrid vehicles are  seeing auto makers and their supplies investing heavily to expand EV supply chains.
# [LOG] [CANDIDATE] There is potential upside to other clay minerals supply given the vast resources in  the US and the willingness of the Chinese government to expand domestic production.
# [LOG] [CANDIDATE] The change in investment plans by non-Chinese participants means China’s market dominance is set to  continue and perhaps expand, at the expense on non-Chinese participants.
# [LOG] [CANDIDATE] © RPM Global USA, Inc  2025  rising prices, but they were also seeing strong demand for batteries as EV sales were expanding rapidly  and therefore, they needed higher inventories to cope with potentially another strong year of growth in 2023,  which ultimately turned out not to be the case.
# [LOG] [CANDIDATE] 17.1.3 Groundwater   In 2018 GHD completed a hydrogeological assessment of the MDE together with an assessment of  dewatering for the expanded open cut.
# [LOG] [CANDIDATE] © RPM Global USA, Inc  2025  23.4 Infrastructure  ▪ Complete and execute the design to expand water storage and distribution.
# [LOG] [CANDIDATE] 23.5 ESG  ▪ Continue with and expand as required, the implementation of the stakeholder engagement program.
# [LOG] ❌ LLM Rejected: 23.5 ESG
# [LOG] [CANDIDATE] The addition of CGP3 will  accelerate the requirement to expand these facilities.
# 📊 Extracted Result:
# Company Name: Albemarle Corporation
# Ticker Symbol: ALB
# Filing Date: 2025-02-12
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing Alexandria Real Estate Equities (ARE)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/1035443/000110465925021383/tm258282d1_ex99-1.htm
# [LOG] 🧠 2 candidate sentences found
# [LOG] [CANDIDATE] Forward-Looking Statements This press release includes “forward-looking
# statements” within the meaning of Section 27A of the Securities Act of 1933, as amended, and Section 21E of the Securities
# Exchange Act of 1934, as amended.
# [LOG] [CANDIDATE] All forward-looking statements are made as of the date of this press
# release, and Alexandria assumes no obligation to update this information.
# 📊 Extracted Result:
# Company Name: Alexandria Real Estate Equities
# Ticker Symbol: ARE
# Filing Date: 2025-03-06
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing Align Technology (ALGN)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/1097149/000109714925000008/algn_omrstockrepurchasex02.htm
# [LOG] 🧠 1 candidate sentences found
# [LOG] [CANDIDATE] Forward-looking statements contained in this news release relating to expectations about future events or results are based upon information available to Align as of the date hereof.
# 📊 Extracted Result:
# Company Name: Align Technology
# Ticker Symbol: ALGN
# Filing Date: 2025-02-25
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing Allegion (ALLE)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/1579241/000157924125000006/exhibit991-pressreleasedat.htm
# [LOG] 🧠 3 candidate sentences found
# [LOG] [CANDIDATE] Non-GAAP Measures This news release includes adjusted non-GAAP financial information which should be considered supplemental to, not a substitute for or superior to, the financial measure calculated in accordance with GAAP.
# [LOG] [CANDIDATE] Further information about the adjusted non-GAAP financial tables is attached to this news release.
# [LOG] [CANDIDATE] All forward-looking statements in this press release are expressly qualified by such cautionary statements and by reference to the underlying assumptions.
# 📊 Extracted Result:
# Company Name: Allegion
# Ticker Symbol: ALLE
# Filing Date: 2025-02-18
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing Alliant Energy (LNT)
# [LOG] EX-99.1: Fallback
# [LOG] No usable text
#
# 📄 Processing Allstate (ALL)
# [LOG] EX-99.1: Fallback
# [LOG] 🧠 2 candidate sentences found
# [LOG] [CANDIDATE] Financial information, including material announcements about The Allstate Corporation, is routinely posted on www.allstateinvestors.com.
# [LOG] [CANDIDATE] Forward-Looking Statements This news release contains “forward-looking statements” that anticipate results based on our estimates, assumptions and plans that are subject to uncertainty.
# 📊 Extracted Result:
# Company Name: Allstate
# Ticker Symbol: ALL
# Filing Date: 2025-03-20
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing Alphabet Inc.(Class A) (GOOGL)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/1652044/000165204425000027/googexhibit99131825.htm
# [LOG] 🧠 2 candidate sentences found
# [LOG] [CANDIDATE] Webcast Alphabet Inc. (NASDAQ: GOOG, GOOGL) will host a webcast to discuss this announcement on Tuesday, March 18, at 6:00am Pacific Time (9:00am Eastern Time).
# [LOG] ❌ LLM Rejected: March 18
# [LOG] [CANDIDATE] Forward-Looking Statements This release includes forward-looking statements within the meaning of the Private Securities Litigation Reform Act of 1995 regarding the acquisition of Wiz by Google.
# 📊 Extracted Result:
# Company Name: Alphabet Inc.(Class A)
# Ticker Symbol: GOOGL
# Filing Date: 2025-03-18
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing Alphabet Inc.(Class C) (GOOG)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/1652044/000165204425000027/googexhibit99131825.htm
# [LOG] 🧠 2 candidate sentences found
# [LOG] [CANDIDATE] Webcast Alphabet Inc. (NASDAQ: GOOG, GOOGL) will host a webcast to discuss this announcement on Tuesday, March 18, at 6:00am Pacific Time (9:00am Eastern Time).
# [LOG] ❌ LLM Rejected: March 18
# [LOG] [CANDIDATE] Forward-Looking Statements This release includes forward-looking statements within the meaning of the Private Securities Litigation Reform Act of 1995 regarding the acquisition of Wiz by Google.
# 📊 Extracted Result:
# Company Name: Alphabet Inc.(Class C)
# Ticker Symbol: GOOG
# Filing Date: 2025-03-18
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing Altria (MO)
# [LOG] EX-99.1: Fallback
# [LOG] 🧠 0 candidate sentences found
# 📊 Extracted Result:
# Company Name: Altria
# Ticker Symbol: MO
# Filing Date: 2025-02-06
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing Amazon (AMZN)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/1018724/000101872425000002/amzn-20241231xex991.htm
# [LOG] 🧠 5 candidate sentences found
# [LOG] [CANDIDATE] EX-99.1 2 amzn-20241231xex991.htm EX-99.1 Document Exhibit 99.1 AMAZON.COM ANNOUNCES FOURTH QUARTER RESULTS SEATTLE—(BUSINESS WIRE) February 6, 2025—Amazon.com, Inc. (NASDAQ: AMZN) today announced financial results for its fourth quarter ended December 31, 2024.
# [LOG] ❌ LLM Rejected: Document Exhibit
# [LOG] [CANDIDATE] Some other highlights since the company’s last earnings announcement include that Amazon: • Delivered at its fastest speeds ever for Prime members in 2024. •
# [LOG] ❌ LLM Rejected: • Delivered
# [LOG] [CANDIDATE] Launched Amazon Haul, a new shopping experience in Amazon’s U.S. shopping app and mobile site, with ultra-low prices. •
# [LOG] ❌ LLM Rejected: Amazon Haul
# [LOG] [CANDIDATE] Announced GROW with SAP on AWS to help customers rapidly deploy SAP’s enterprise resource planning. •
# [LOG] [CANDIDATE] Launched AWS Asia Pacific (Thailand) and AWS Mexico (Central) Regions. •
# 📊 Extracted Result:
# Company Name: Amazon
# Ticker Symbol: AMZN
# Filing Date: 2025-02-06
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing Amcor (AMCR)
# [LOG] EX-99.1: Fallback
# [LOG] 🧠 7 candidate sentences found
# [LOG] [CANDIDATE] Guarantee” means the guarantee by each
# Guarantor of any Security authenticated and delivered pursuant to this Indenture; provided, however, that the Guarantor providing such
# Guarantee has not been released as a Guarantor of such Security pursuant to Section 1302 hereof. “
# [LOG] [CANDIDATE] New Guarantor” means each Person who
# becomes a Guarantor in relation to the Securities by executing a New Guarantor Supplemental Indenture, in each case unless and until
# such Guarantor has been released from its Guarantee pursuant to Section 1302. “
# [LOG] ❌ LLM Rejected: Supplemental Indenture
# [LOG] [CANDIDATE] Officer’s Certificate of Release”
# means a certificate signed by any Director or Authorized Officer or Secretary of the Issuer and delivered to the Trustee certifying as
# to the facts required by Section 1302 hereof. “
# [LOG] ❌ LLM Rejected: Authorized Officer
# [LOG] [CANDIDATE] In accordance with Section 1302 of the Indenture,
# any or all of the Subsidiary Guarantors may be released at any time from their respective Guarantees and other obligations under the
# Indenture and the Securities without the consent of any Holder.
# [LOG] [CANDIDATE] Release
# of Subsidiary Guarantors .
# [LOG] ❌ LLM Rejected: Subsidiary Guarantors
# [LOG] [CANDIDATE] Any or all of the Subsidiary Guarantors may be released
# at any time from their respective Guarantees and other obligations under this Indenture without the consent of any Holder.
# [LOG] [CANDIDATE] Notwithstanding the foregoing, the release of a Subsidiary of the Parent Guarantor as a Subsidiary
# Guarantor shall not preclude such Subsidiary subsequently becoming a Guarantor if, while the Securities are Outstanding, such Subsidiary
# becomes a Relevant Guarantor subsequent to such release. * * *
# 📊 Extracted Result:
# Company Name: Amcor
# Ticker Symbol: AMCR
# Filing Date: 2025-03-17
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing Ameren (AEE)
# [LOG] EX-99.1: Fallback
# [LOG] 🧠 1 candidate sentences found
# [LOG] [CANDIDATE] Upon the authorization by the Representatives of the release of the Securities, the several Underwriters propose to offer the Securities
# for sale upon the terms and conditions set forth in the Prospectus.
# 📊 Extracted Result:
# Company Name: Ameren
# Ticker Symbol: AEE
# Filing Date: 2025-03-07
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing American Electric Power (AEP)
# [LOG] EX-99.1: Fallback
# [LOG] No usable text
#
# 📄 Processing American Express (AXP)
# [LOG] EX-99.1: Fallback
# [LOG] No usable text
#
# 📄 Processing American International Group (AIG)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/5272/000000527225000014/a991-jpboardappointment.htm
# [LOG] 🧠 1 candidate sentences found
# [LOG] [CANDIDATE] This website with additional information about AIG has been provided as a convenience, and the information contained on such website is not incorporated by reference into this press release.
# 📊 Extracted Result:
# Company Name: American International Group
# Ticker Symbol: AIG
# Filing Date: 2025-02-20
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing American Tower (AMT)
# [LOG] EX-99.1: Fallback
# [LOG] No usable text
#
# 📄 Processing American Water Works (AWK)
# [LOG] EX-99.1: Fallback
# [LOG] No usable text
#
# 📄 Processing Ameriprise Financial (AMP)
# [LOG] EX-99.1: Fallback
# [LOG] 🧠 2 candidate sentences found
# [LOG] [CANDIDATE] Upon authorization by the Representatives of the release of the Notes, the Underwriters propose to offer the Notes to the public as set
# forth in the Prospectus.
# [LOG] [CANDIDATE] Receipt of a party’s executed signature page to this
# Agreement by email, facsimile or other electronic transmission with permission to release such signature page shall constitute effective
# execution and delivery of this Agreement by such party.
# 📊 Extracted Result:
# Company Name: Ameriprise Financial
# Ticker Symbol: AMP
# Filing Date: 2025-02-28
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing Ametek (AME)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/1037868/000103786825000008/exhibit-991divinc2x7x25.htm
# [LOG] 🧠 0 candidate sentences found
# 📊 Extracted Result:
# Company Name: Ametek
# Ticker Symbol: AME
# Filing Date: 2025-02-10
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing Amgen (AMGN)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/318154/000031815425000005/amgn-20241231earningsrelea.htm
# [LOG] 🧠 2 candidate sentences found
# [LOG] [CANDIDATE] The Company uses the non-GAAP financial measures set forth in the news release in connection with its own budgeting and financial planning internally to evaluate the performance of the business, including to allocate resources and to evaluate results relative to incentive compensation targets.
# [LOG] [CANDIDATE] Forward-Looking Statements This news release contains forward-looking statements that are based on the current expectations and beliefs of Amgen.
# 📊 Extracted Result:
# Company Name: Amgen
# Ticker Symbol: AMGN
# Filing Date: 2025-02-04
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing Amphenol (APH)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/820313/000110465925008414/tm255016d1_ex99-1.htm
# [LOG] 🧠 3 candidate sentences found
# [LOG] [CANDIDATE] EX-99.1 2 tm255016d1_ex99-1.htm EXHIBIT 99.1 Exhibit 99.1 Amphenol News
# Release World
# Headquarters 35 8
# Hall Avenue Wallingford, CT 06492 Telephone (203) 265-8900 AMPHENOL CORPORATION
# COMPLETES ACQUISITION
# OF OWN AND DAS BUSINESSES FROM COMMSCOPE Wallingford, Connecticut, February 3,
# 2025.
# 📊 Extracted Result:
# Company Name: Amphenol
# Ticker Symbol: APH
# Filing Date: 2025-02-03
# Product Name: Avenue Wallingford
# Product Description: Amphenol completes acquisition of its own businesses from Commscope for $1 billion, adding Hall Avenue's high-voltage components to its portfolio.
# 💾 Saved: Avenue Wallingford → extracted_data.csv
#
# 📄 Processing Analog Devices (ADI)
# [LOG] EX-99.1: Fallback
# [LOG] No usable text
#
# 📄 Processing Ansys (ANSS)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/1013462/000101346225000008/anssex991-pressrelease2024.htm
# [LOG] 🧠 5 candidate sentences found
# [LOG] [CANDIDATE] Q4 2024 Financial Results // 1 As previously announced, on January 15, 2024, Ansys entered into a definitive agreement with Synopsys, Inc. ("Synopsys") under which Synopsys will acquire Ansys.
# 📊 Extracted Result:
# Company Name: Ansys
# Ticker Symbol: ANSS
# Filing Date: 2025-02-19
# Product Name: Synopsys"
# Product Description: Ansys has entered into a definitive agreement to acquire Synopsys, Inc. for $27.50 per share in cash and stock, pending certain conditions.
# 💾 Saved: Synopsys" → extracted_data.csv
#
# 📄 Processing Aon plc (AON)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/315293/000119312525055237/d903628dex991.htm
# [LOG] 🧠 0 candidate sentences found
# 📊 Extracted Result:
# Company Name: Aon plc
# Ticker Symbol: AON
# Filing Date: 2025-03-17
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing APA Corporation (APA)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/1841666/000119312525038008/d886649dex991.htm
# [LOG] 🧠 7 candidate sentences found
# [LOG] [CANDIDATE] HOUSTON, Feb. 26, 2025 – APA Corporation (Nasdaq: APA) today announced its financial and operational results for the fourth quarter and full-year 2024.
# [LOG] [CANDIDATE] Page 1 of 5 APA CORPORATION ANNOUNCES FOURTH-QUARTER AND FULL-YEAR 2024 FINANCIAL AND OPERATIONAL
# RESULTS During the year, APA generated $841 million of free cash flow, repurchased $246 million of common
# stock, and paid $353 million in dividends.
# [LOG] [CANDIDATE] Page 2 of 5 APA CORPORATION ANNOUNCES FOURTH-QUARTER AND FULL-YEAR 2024 FINANCIAL AND OPERATIONAL
# RESULTS “Our 2025 plan builds on the progress achieved in 2024,” continued Christmann. “
# [LOG] [CANDIDATE] APA posts announcements, operational updates, investor information and press releases on its website, www.apacorp.com .
# [LOG] [CANDIDATE] Forward-Looking Statements This news
# release contains forward-looking statements within the meaning of Section 27A of the Securities Act of 1933 and Section 21E of the Securities Exchange Act of 1934.
# [LOG] [CANDIDATE] Any forward-looking
# statement made in this news release speaks only as of the date on which it is made.
# [LOG] [CANDIDATE] APA may use certain terms in this news
# release, such as “resources,” “potential resources,” “resource potential,” “estimated net reserves,” “recoverable reserves,” and other similar terms that the SEC guidelines strictly prohibit APA from
# including in filings with the SEC.
# 📊 Extracted Result:
# Company Name: APA Corporation
# Ticker Symbol: APA
# Filing Date: 2025-02-27
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing Apollo Global Management (APO)
# [LOG] EX-99.1: Fallback
# [LOG] No usable text
#
# 📄 Processing Apple Inc. (AAPL)
# [LOG] EX-99.1: Fallback
# [LOG] No usable text
#
# 📄 Processing Applied Materials (AMAT)
# [LOG] EX-99.1: Fallback
# [LOG] No usable text
#
# 📄 Processing Aptiv (APTV)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/1521332/000152133225000006/aptv2024ex991.htm
# [LOG] 🧠 4 candidate sentences found
# [LOG] [CANDIDATE] Use of Non-GAAP Financial Information This press release contains information about Aptiv’s financial results which are not presented in accordance with GAAP.
# [LOG] [CANDIDATE] Management believes the non-GAAP financial measures used in this press release are useful to both management and investors in their analysis of the Company’s financial position, results of operations and liquidity.
# [LOG] [CANDIDATE] Such non-GAAP financial measures are reconciled to the most directly comparable GAAP financial measures in the attached supplemental schedules at the end of this press release.
# [LOG] [CANDIDATE] Forward-Looking Statements This press release, as well as other statements made by Aptiv PLC (the “Company”), contain forward-looking statements that reflect, when made, the Company’s current views with respect to current events, certain investments and acquisitions and financial performance.
# 📊 Extracted Result:
# Company Name: Aptiv
# Ticker Symbol: APTV
# Filing Date: 2025-02-06
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing Arch Capital Group (ACGL)
# [LOG] EX-99.1: Fallback
# [LOG] No usable text
#
# 📄 Processing Archer Daniels Midland (ADM)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/7084/000000708425000005/adm-ex991_20241231xq4.htm
# [LOG] 🧠 5 candidate sentences found
# [LOG] [CANDIDATE] Targeted Actions to Deliver Cost Savings The Company announced today targeted actions to deliver between $500 - $750 million in cost savings over the next 3 - 5 years.
# 📊 Extracted Result:
# Company Name: Archer Daniels Midland
# Ticker Symbol: ADM
# Filing Date: 2025-02-04
# Product Name: Targeted Actions
# Product Description: Archer Daniels Midland's Targeted Actions initiative aims to deliver significant cost savings through strategic efforts within three to five years, targeting between $500 - $750 mi
# 💾 Saved: Targeted Actions → extracted_data.csv
#
# 📄 Processing Arista Networks (ANET)
# [LOG] EX-99.1: Fallback
# [LOG] No usable text
#
# 📄 Processing Arthur J. Gallagher & Co. (AJG)
# [LOG] EX-99.1: Fallback
# [LOG] No usable text
#
# 📄 Processing Assurant (AIZ)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/1267238/000126723825000005/aiz-20241231exx991pressrel.htm
# [LOG] 🧠 3 candidate sentences found
# [LOG] [CANDIDATE] reportable catastrophes, per diluted share 4 5.54 4.90 13% 20.35 17.13 19% Some of the metrics throughout this press release are non-GAAP measures of performance.
# [LOG] [CANDIDATE] Full-year 2024 net earned premiums, fees and other income increased 5 percent compared to 2023, or similar on a constant currency basis 5 , primarily due to contributions from newly launched trade-in programs and device protection programs.
# [LOG] [CANDIDATE] Any forward-looking statements contained in this news release or its exhibits are based upon our historical performance and on current plans, estimates and expectations.
# 📊 Extracted Result:
# Company Name: Assurant
# Ticker Symbol: AIZ
# Filing Date: 2025-02-11
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing AT&T (T)
# [LOG] EX-99.1: Fallback
# [LOG] No usable text
#
# 📄 Processing Atmos Energy (ATO)
# [LOG] EX-99.1: Fallback
# [LOG] No usable text
#
# 📄 Processing Autodesk (ADSK)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/769397/000076939725000013/q425pressrelease.htm
# [LOG] 🧠 7 candidate sentences found
# [LOG] [CANDIDATE] EX-99.1 2 q425pressrelease.htm EX-99.1 Document AUTODESK, INC.
# [LOG] [CANDIDATE] The completion of the new transaction model launch in the fourth quarter marked a significant milestone, and we have now initiated the optimization phase of our sales and marketing plan.
# [LOG] [CANDIDATE] Following a review of our business, Autodesk has announced today a worldwide restructuring plan that includes a reduction in force that will result in the termination of approximately 9 percent of our workforce, or approximately 1,350 employees, other exit costs, and facility reductions.
# [LOG] [CANDIDATE] Maintenance Plan: Our maintenance plans provide our customers with a cost effective and predictable budgetary option to obtain the productivity benefits of our new releases and enhancements when and if released during the term of their contracts.
# [LOG] [CANDIDATE] Accordingly, you should monitor our investor relations website in addition to following our press releases, SEC filings and public conference calls and webcasts.
# [LOG] [CANDIDATE] The following table shows Autodesk's GAAP results reconciled to non-GAAP results included in this release.
# [LOG] [CANDIDATE] The following table shows Autodesk's GAAP business outlook reconciled to non-GAAP business outlook included in this release.
# 📊 Extracted Result:
# Company Name: Autodesk
# Ticker Symbol: ADSK
# Filing Date: 2025-02-27
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing Automatic Data Processing (ADP)
# [LOG] EX-99.1: Fallback
# [LOG] 🧠 3 candidate sentences found
# [LOG] [CANDIDATE] Please refer to the accompanying financial tables at the end of this release for a discussion of why ADP believes these measures are important and for a reconciliation of non-GAAP financial measures to their closest comparable GAAP financial measures.
# [LOG] [CANDIDATE] Investor Webcast Today As previously announced, ADP will host a conference call for financial analysts today, Wednesday, January 29, 2025 at 8:30 a.m. ET.
# [LOG] [CANDIDATE] ADP news releases, current financial information, SEC filings, and Investor Relations presentations are posted to ADP’s website at investors.adp.com .
# 📊 Extracted Result:
# Company Name: Automatic Data Processing
# Ticker Symbol: ADP
# Filing Date: 2025-01-29
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing AutoZone (AZO)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/866787/000117184325001229/exh_991.htm
# [LOG] 🧠 1 candidate sentences found
# [LOG] [CANDIDATE] This release includes certain financial information not derived in accordance with generally accepted accounting principles (“GAAP”).
# 📊 Extracted Result:
# Company Name: AutoZone
# Ticker Symbol: AZO
# Filing Date: 2025-03-04
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing AvalonBay Communities (AVB)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/915912/000091591225000003/q42024ex-991.htm
# [LOG] 🧠 15 candidate sentences found
# [LOG] [CANDIDATE] EX-99.1 2 q42024ex-991.htm EX-99.1 Document Exhibit 99.1 For Immediate News Release February 5, 2025 AVALONBAY COMMUNITIES, INC.
# [LOG] ❌ LLM Rejected: Document Exhibit
# [LOG] [CANDIDATE] 2) See full release for discussion of variances.
# [LOG] [CANDIDATE] 2) See full release for discussion of variances.
# [LOG] [CANDIDATE] The Company’s annualized Net Debt-to-Core EBITDAre (as defined in this release) for the fourth quarter of 2024 was 4.2 times and Unencumbered NOI (as defined in this release) for the year ended December 31, 2024 was 95%.
# [LOG] [CANDIDATE] Other Matters The Company will hold a conference call on February 6, 2025 at 1:00 PM ET to review and answer questions about this release, its fourth quarter and full year 2024 results, the Attachments (described below) and related matters.
# [LOG] ❌ LLM Rejected: Other Matters
# [LOG] [CANDIDATE] The Company produces Earnings Release Attachments (the "Attachments") that provide detailed information regarding operating, development, redevelopment, disposition and acquisition activity.
# [LOG] ❌ LLM Rejected: Attachments"
# [LOG] [CANDIDATE] These Attachments are considered a part of this earnings release and are available in full with this earnings release via the Company's website at https://investors.avalonbay.com .
# [LOG] ❌ LLM Rejected: These Attachments
# [LOG] [CANDIDATE] To receive future press releases via e-mail, please submit a request through https://investors.avalonbay.com/news-events/email-alerts.
# [LOG] [CANDIDATE] In addition to the Attachments, the Company is providing a teleconference presentation that will be available on the Company's website at https://investors.avalonbay.com subsequent to this release and before the market opens on February 6, 2025.
# [LOG] [CANDIDATE] Forward-Looking Statements This release, including its Attachments, contains “forward-looking statements” within the meaning of Section 27A of the Securities Act of 1933, as amended, and Section 21E of the Securities Exchange Act of 1934, as amended.
# [LOG] [CANDIDATE] The Company does not undertake a duty to update these forward-looking statements, and therefore they may not represent the Company’s estimates and assumptions after the date of this release.
# [LOG] [CANDIDATE] Attachment 14 is included in the full earnings release available at the Company’s website at https://investors.avalonbay.com.
# [LOG] [CANDIDATE] Projected FFO and Projected Core FFO , as provided within this release in the Company’s outlook, are calculated on a basis consistent with historical FFO and Core FFO, and are therefore considered to be appropriate supplemental measures to projected net income from projected operating performance.
# [LOG] [CANDIDATE] However, in this release the Company has not given a projection of NOI on a company-wide basis.
# [LOG] [CANDIDATE] There can be no assurance that the communities under development will achieve the Projected NOI as described in this release.
# 📊 Extracted Result:
# Company Name: AvalonBay Communities
# Ticker Symbol: AVB
# Filing Date: 2025-02-06
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing Avery Dennison (AVY)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/8818/000119312525016229/d178536dex991.htm
# [LOG] 🧠 3 candidate sentences found
# [LOG] [CANDIDATE] EX-99.1 2 d178536dex991.htm EX-99.1 EX-99.1 Exhibit 99.1 For Immediate Release AVERY DENNISON ANNOUNCES FOURTH
# QUARTER AND FULL YEAR 2024 RESULTS Highlights: ● FY24 Reported EPS of $8.73 ¡ FY24 Adjusted EPS of $9.43, up 19% ● FY24 Net sales of $8.8 billion, up 4.7% ¡ Sales change ex.
# [LOG] ❌ LLM Rejected: RESULTS Highlights
# 📊 Extracted Result:
# Company Name: Avery Dennison
# Ticker Symbol: AVY
# Filing Date: 2025-01-30
# Product Name: Adjusted EPS
# Product Description: Avery Dennison reports fourth-quarter and full-year 2024 earnings growth with a 19% increase in reported EPS to $8.73, driven by net sales gains of 4.7%.
# 💾 Saved: Adjusted EPS → extracted_data.csv
#
# 📄 Processing Axon Enterprise (AXON)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/1069183/000106918325000031/axon-20250311x8kxexhibit991.htm
# [LOG] 🧠 2 candidate sentences found
# [LOG] [CANDIDATE] The total offering size was increased from the previously announced total offering size of $1,500.0 million aggregate principal amount of Notes.
# [LOG] [CANDIDATE] This press release does not constitute an offer to purchase or a redemption notice in respect of the Existing Convertible Notes.
# 📊 Extracted Result:
# Company Name: Axon Enterprise
# Ticker Symbol: AXON
# Filing Date: 2025-03-11
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing Baker Hughes (BKR)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/1701605/000170160525000068/bkrisrecast2025.htm
# [LOG] 🧠 0 candidate sentences found
# 📊 Extracted Result:
# Company Name: Baker Hughes
# Ticker Symbol: BKR
# Filing Date: 2025-03-25
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing Ball Corporation (BALL)
# [LOG] EX-99.1: Fallback
# [LOG] No usable text
#
# 📄 Processing Bank of America (BAC)
# [LOG] EX-99.1: Fallback
# [LOG] No usable text
#
# 📄 Processing Baxter International (BAX)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/10456/000162828025012724/ex991.htm
# [LOG] 🧠 0 candidate sentences found
# 📊 Extracted Result:
# Company Name: Baxter International
# Ticker Symbol: BAX
# Filing Date: 2025-03-14
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing Becton Dickinson (BDX)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/10795/000001079525000019/ex99112312024.htm
# [LOG] 🧠 7 candidate sentences found
# [LOG] [CANDIDATE] Recent Business Highlights • The company announced the BD board authorized the repurchase of up to 10 million shares of BD common stock in addition to the shares that remain available under the board's previous authorization in 2021. •
# [LOG] [CANDIDATE] BD Medical: • The Medication Delivery Solutions business unit announced: ◦ Additional investments in its U.S. manufacturing network to add capacity for critical medical devices , including syringes, needles and IV catheters, to meet the ongoing needs of the nation's health care system.
# [LOG] [CANDIDATE] BD Life Sciences: • The Specimen Management business unit announced an expansion of innovative fingertip blood testing for use by U.S. health systems and other large provider networks in settings like urgent cares, doctor offices and other ambulatory care settings.
# [LOG] [CANDIDATE] The company also announced the assay will be used in a first of its kind Human Papillomavirus (HPV) self-collection study to improve cervical cancer screening in underserved communities.
# [LOG] [CANDIDATE] The Biosciences business unit announced a collaboration with Biosero to enable robotic integration with BD flow cytometers to accelerate drug discovery and development.
# [LOG] [CANDIDATE] Non-GAAP Financial Measures/Financial Tables This news release contains certain non-GAAP financial measures.
# 📊 Extracted Result:
# Company Name: Becton Dickinson
# Ticker Symbol: BDX
# Filing Date: 2025-02-05
# Product Name: /Financial
# Product Description: This report presents non-GAAP financial measures and tables, providing insights into Company performance and trends for Q1 2023.
# 💾 Saved: /Financial → extracted_data.csv
#
# 📄 Processing Best Buy (BBY)
# [LOG] EX-99.1: Fallback
# [LOG] 🧠 7 candidate sentences found
# [LOG] [CANDIDATE] For GAAP to non-GAAP reconciliations of the adjusted measures used throughout this release, please refer to the attached supporting schedule.
# [LOG] [CANDIDATE] This leads to our comparable sales guide in the range of flat to 2% growth for the year, with growth weighted more to the second half of the year based on the timing of product launches and initiatives.”
# [LOG] [CANDIDATE] ﻿ Today, the company announced its board of directors approved a 1% increase in the regular quarterly dividend to $0.95 per share.
# [LOG] [CANDIDATE] For GAAP to non-GAAP reconciliations of the adjusted measures used throughout this release, please refer to the attached supporting schedule .
# [LOG] [CANDIDATE] ﻿ Forward-Looking and Cautionary Statements: This release contains forward-looking statements within the meaning of the Private Securities Litigation Reform Act of 1995 as contained in Section 27A of the Securities Act of 1933 and Section 21E of the Securities Exchange Act of 1934.
# [LOG] [CANDIDATE] These non-GAAP financial measures should be considered in addition to, and not superior to or as a substitute for, the GAAP financial measures presented in this earnings release and the company’s financial statements and other publicly filed reports.
# [LOG] [CANDIDATE] Additional details regarding these adjustments are included in the Reconciliation of Non-GAAP Financial Measures schedule within the company’s earnings release s . (
# 📊 Extracted Result:
# Company Name: Best Buy
# Ticker Symbol: BBY
# Filing Date: 2025-03-04
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing Bio-Techne (TECH)
# [LOG] EX-99.1: Fallback
# [LOG] No usable text
#
# 📄 Processing Biogen (BIIB)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/875045/000087504525000004/exhibit991-q42024pressrele.htm
# [LOG] 🧠 7 candidate sentences found
# [LOG] [CANDIDATE] We delivered continued revenue growth from our ongoing product launches including LEQEMBI, where we believe there remains a significant long-term opportunity.
# [LOG] [CANDIDATE] A reconciliation of GAAP to Non-GAAP financial measures can be found in Table 4 at the end of this news release.
# [LOG] [CANDIDATE] The decrease in full year 2024 GAAP and Non-GAAP cost of sales as a percentage of total revenue was driven primarily by product mix, particularly the year-over-year increase in revenue from new product launches, a decrease in contract manufacturing revenue, and lower idle capacity charges. •
# [LOG] [CANDIDATE] The increase in fourth quarter 2024 GAAP and Non-GAAP SG&A was driven primarily by sales and marketing spend to support product launches, partially offset by savings from the Company's Fit for Growth initiative. •
# [LOG] [CANDIDATE] Total revenue is expected to decline by a mid-single digit percentage for 2025 compared to 2024 as further declines in multiple sclerosis product revenue are expected to be partially offset by increases in revenue from product launches.
# [LOG] [CANDIDATE] 4 • In February 2025, Royalty Pharma plc announced that it had entered into an agreement with Biogen to provide research and development funding of up to $250 million for litifilimab.
# [LOG] [CANDIDATE] These statements speak only as of the date of this press release and are based on information and estimates available to us at this time.
# 📊 Extracted Result:
# Company Name: Biogen
# Ticker Symbol: BIIB
# Filing Date: 2025-02-12
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing BlackRock (BLK)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/2012383/000119312525044184/d919939dex991.htm
# [LOG] 🧠 0 candidate sentences found
# 📊 Extracted Result:
# Company Name: BlackRock
# Ticker Symbol: BLK
# Filing Date: 2025-03-03
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# ...
# [LOG] ❌ LLM Rejected: Syndax Pharmaceuticals
# [LOG] ❌ LLM Rejected: Niktimvo™
# [LOG] [CANDIDATE] Niktimvo is now commercially available in the U.S. and the commercial launch is underway. •
# 📊 Extracted Result:
# Company Name: Incyte
# Ticker Symbol: INCY
# Filing Date: 2025-02-10
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing Ingersoll Rand (IR)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/1699150/000162828025005443/ir2024q4ex991.htm
# [LOG] 🧠 1 candidate sentences found
# [LOG] [CANDIDATE] Any forward-looking statements speak only as of the date of this release.
# 📊 Extracted Result:
# Company Name: Ingersoll Rand
# Ticker Symbol: IR
# Filing Date: 2025-02-13
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing Insulet Corporation (PODD)
# [LOG] EX-99.1: Fallback
# [LOG] 🧠 15 candidate sentences found
# [LOG] [CANDIDATE] Guarantor ” means any Restricted Subsidiary that Guarantees the Notes until such Note Guarantee
# is released in accordance with the terms of this Indenture.
# [LOG] [CANDIDATE] Any Lien created for the benefit of the Holders
# pursuant to the last clause of the preceding sentence shall provide by its terms that such Lien shall be automatically and unconditionally released and discharged upon the release and discharge of the Initial Lien.
# [LOG] [CANDIDATE] d) Each of such Guarantee shall also be released in accordance with the provisions of this Indenture described under Article X .
# [LOG] ❌ LLM Rejected: Article X
# [LOG] [CANDIDATE] The Issuer will publicly announce the results of the Change of
# Control Offer on or as soon as practicable after the Change of Control Payment Date.
# [LOG] [CANDIDATE] e) During the Suspension Period, the Note
# Guarantees of the Guarantors shall be released and any obligation to grant further Note Guarantees shall be suspended.
# [LOG] [CANDIDATE] c) The Successor Issuer will succeed to, and be substituted for, and may exercise every right and power of, the Issuer under
# the Notes and this Indenture, and the Issuer will automatically and unconditionally be released and discharged from its obligations under the Notes and this Indenture. (
# [LOG] [CANDIDATE] Each Guarantor agrees that its Guarantee herein shall remain in full force and
# effect until payment in full of all the Guaranteed Obligations or such Guarantor is released from its Guarantee in compliance with Section 10.02 , Article VIII or Article XI .
# [LOG] ❌ LLM Rejected: Article VIII
# [LOG] ❌ LLM Rejected: Article XI
# [LOG] [CANDIDATE] SECTION 10.02 Limitation on Liability; Termination, Release and Discharge . (
# [LOG] [CANDIDATE] -142- (c) The Issuer shall provide the Trustee with written notice of any such release of a
# Guarantor; provided that failure to deliver such notice shall not affect such release.
# [LOG] [CANDIDATE] Each Holder by accepting a Note waives and releases all such liability.
# [LOG] [CANDIDATE] The waiver and release are part of the consideration for issuance of the Notes.
# [LOG] [CANDIDATE] Each Holder by accepting a Note waives and releases all such liability.
# [LOG] [CANDIDATE] The waiver and release are part of the consideration for issuance of the Notes.
# [LOG] [CANDIDATE] Release of Guarantee .
# [LOG] [CANDIDATE] This Guarantee shall be released in accordance with Section 10.02 of
# the Indenture.
# 📊 Extracted Result:
# Company Name: Insulet Corporation
# Ticker Symbol: PODD
# Filing Date: 2025-03-21
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing Intel (INTC)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/50863/000005086325000036/a03102025form8-kex991.htm
# [LOG] 🧠 3 candidate sentences found
# [LOG] [CANDIDATE] Santa Clara, CA 95054-1549 News Release Intel Appoints Lip-Bu Tan as Chief Executive Officer Tan to join Intel board of directors.
# [LOG] [CANDIDATE] S ANTA CLARA, Calif., March 12, 2025 – Intel Corporation (Nasdaq: INTC) today announced that its board of directors has appointed Lip-Bu Tan, an accomplished technology leader with deep semiconductor industry experience, as chief executive officer, effective March 18.
# [LOG] ❌ LLM Rejected: March 12
# [LOG] [CANDIDATE] During his time as CEO, Cadence more than doubled its revenue, expanded operating margins and delivered a stock price appreciation of more than 3,200%.
# 📊 Extracted Result:
# Company Name: Intel
# Ticker Symbol: INTC
# Filing Date: 2025-03-14
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing Intercontinental Exchange (ICE)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/1571949/000110465925009884/tm255453d1_ex99-1.htm
# [LOG] 🧠 2 candidate sentences found
# [LOG] [CANDIDATE] Please refer to the reconciliation of non-GAAP financial measures
# included in this press release for more information on our adjusted operating expenses, adjusted operating income, adjusted operating
# margin, adjusted net income, adjusted diluted EPS and adjusted free cash flow.
# [LOG] [CANDIDATE] Safe Harbor Statement under the Private Securities
# Litigation Reform Act of 1995 - Statements in this press release regarding ICE's business that are not historical facts are "forward-looking
# statements" that involve risks and uncertainties.
# [LOG] ❌ LLM Rejected: Safe Harbor
# 📊 Extracted Result:
# Company Name: Intercontinental Exchange
# Ticker Symbol: ICE
# Filing Date: 2025-02-06
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing International Flavors & Fragrances (IFF)
# [LOG] EX-99.1: Fallback
# [LOG] No usable text
#
# 📄 Processing International Paper (IP)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/51434/000119312525061846/d887733dex991.htm
# [LOG] 🧠 0 candidate sentences found
# 📊 Extracted Result:
# Company Name: International Paper
# Ticker Symbol: IP
# Filing Date: 2025-03-25
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing Interpublic Group of Companies (The) (IPG)
# [LOG] EX-99.1: Fallback
# [LOG] No usable text
#
# 📄 Processing Intuit (INTU)
# [LOG] EX-99.1: Fallback
# [LOG] 🧠 6 candidate sentences found
# [LOG] [CANDIDATE] We are confident in delivering double-digit revenue growth and expanding margin this year, and we are reiterating our full year guidance for fiscal 2025."
# [LOG] [CANDIDATE] 3 Intuit announced guidance for the third quarter of fiscal year 2025, which ends April 30.
# [LOG] ❌ LLM Rejected: 3
# [LOG] [CANDIDATE] About Non-GAAP Financial Measures This press release and the accompanying tables include non-GAAP financial measures.
# [LOG] [CANDIDATE] ABOUT NON-GAAP FINANCIAL MEASURES The accompanying press release dated February 25, 2025 contains non-GAAP financial measures.
# [LOG] [CANDIDATE] Table B1, Table B2, and Table E reconcile the non-GAAP financial measures in that press release to the most directly comparable financial measures prepared in accordance with Generally Accepted Accounting Principles (GAAP).
# [LOG] [CANDIDATE] The reconciliations of the forward-looking non-GAAP financial measures to the most directly comparable GAAP financial measures in Table E include all information reasonably available to Intuit at the date of this press release.
# 📊 Extracted Result:
# Company Name: Intuit
# Ticker Symbol: INTU
# Filing Date: 2025-02-25
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing Intuitive Surgical (ISRG)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/1035267/000103526725000008/q424ex-991earningsrelease.htm
# [LOG] 🧠 6 candidate sentences found
# [LOG] [CANDIDATE] EX-99.1 2 q424ex-991earningsrelease.htm EX-99.1 Document Exhibit 99.1 Contact: Investor Relations (408) 523-2161 INTUITIVE ANNOUNCES FOURTH QUARTER EARNINGS SUNNYVALE, CALIF.
# 📊 Extracted Result:
# Company Name: Intuitive Surgical
# Ticker Symbol: ISRG
# Filing Date: 2025-01-23
# Product Name: Document Exhibit
# Product Description: Intuitive Surgical's document exhibit provides detailed information about its fourth quarter earnings for Fiscal Year 2024.
# 💾 Saved: Document Exhibit → extracted_data.csv
#
# 📄 Processing Invesco (IVZ)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/914208/000091420825000117/ivzaumexhibit991-0225.htm
# [LOG] 🧠 0 candidate sentences found
# 📊 Extracted Result:
# Company Name: Invesco
# Ticker Symbol: IVZ
# Filing Date: 2025-03-11
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing Invitation Homes (INVH)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/1687229/000168722925000011/investorpresentation_mar.htm
# [LOG] 🧠 1 candidate sentences found
# [LOG] [CANDIDATE] These factors should not be construed as exhaustive and should be read in conjunction with the other cautionary statements that are included in this release, in the Annual Report, and in the Company’s other periodic filings.
# 📊 Extracted Result:
# Company Name: Invitation Homes
# Ticker Symbol: INVH
# Filing Date: 2025-02-28
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing IQVIA (IQV)
# [LOG] EX-99.1: Fallback
# [LOG] 🧠 5 candidate sentences found
# [LOG] [CANDIDATE] Any change in
# such rate announced by the Administrative Agent shall take effect at the opening of business on the day specified in the public announcement of such change. “
# [LOG] [CANDIDATE] Euros” means the lawful currency of the Participating Member States
# introduced in accordance with the EMU Legislation. “
# [LOG] [CANDIDATE] Release” means any
# spilling, leaking, pumping, pouring, emitting, emptying, discharge, injecting, escaping, leaching, dumping, disposing, depositing or migration into the Environment.
# [LOG] [CANDIDATE] TARGET2 ” means the Trans-European Automated Real-time Gross Settlement Express Transfer
# payment system which utilizes a single shared platform and which was launched on November 19, 2007. “
# [LOG] ❌ LLM Rejected: November
# [LOG] [CANDIDATE] At any time that
# Base Rate Loans are outstanding, the Administrative Agent shall notify the Parent Borrower and the Lenders of any change in the Administrative Agent’s prime rate used in determining the Base Rate promptly following the public announcement of
# such change. (
# 📊 Extracted Result:
# Company Name: IQVIA
# Ticker Symbol: IQV
# Filing Date: 2025-03-10
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing Iron Mountain (IRM)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/1020569/000110465925014194/tm256382d1_ex99-1.htm
# [LOG] 🧠 0 candidate sentences found
# 📊 Extracted Result:
# Company Name: Iron Mountain
# Ticker Symbol: IRM
# Filing Date: 2025-02-14
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing J.B. Hunt (JBHT)
# [LOG] EX-99.1: Fallback
# [LOG] 🧠 0 candidate sentences found
# 📊 Extracted Result:
# Company Name: J.B. Hunt
# Ticker Symbol: JBHT
# Filing Date: 2025-03-13
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing Jabil (JBL)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/898293/000162828025014001/jbl-20250320ex991.htm
# [LOG] 🧠 2 candidate sentences found
# [LOG] [CANDIDATE] The statements in this release are based on current expectations, forecasts and assumptions involving risks and uncertainties that could cause actual outcomes and results to differ materially from our current expectations.
# [LOG] [CANDIDATE] Supplemental Information Regarding Non-GAAP Financial Measures: Jabil provides supplemental, non-GAAP financial measures in this release to facilitate evaluation of Jabil’s core operating performance.
# 📊 Extracted Result:
# Company Name: Jabil
# Ticker Symbol: JBL
# Filing Date: 2025-03-20
# Product Name: Supplemental Information
# Product Description: Jabil releases supplemental non-GAAP financial information to evaluate core operating performance.
# 💾 Saved: Supplemental Information → extracted_data.csv
#
# 📄 Processing Jack Henry & Associates (JKHY)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/779152/000077915225000007/jkhy-20241231xex99pressrel.htm
# [LOG] 🧠 2 candidate sentences found
# [LOG] [CANDIDATE] Statements made in this news release that are not historical facts are "forward-looking statements" within the meaning of the Private Securities Litigation Reform Act of 1995, Section 27A of the Securities Act of 1933 and Section 21E of the Securities Exchange Act of 1934.
# [LOG] [CANDIDATE] Any forward-looking statement made in this news release speaks only as of the date of the news release, and the Company expressly disclaims any obligation to publicly update or revise any forward-looking statement, whether because of new information, future events or otherwise.
# 📊 Extracted Result:
# Company Name: Jack Henry & Associates
# Ticker Symbol: JKHY
# Filing Date: 2025-02-04
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing Jacobs Solutions (J)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/52988/000005298825000020/jacobs-equityfordebtexchan.htm
# [LOG] 🧠 4 candidate sentences found
# [LOG] [CANDIDATE] 1 Jacobs' Chair and CEO Bob Pragada commented, "We are pleased to have successfully completed this equity for debt exchange, achieving value for our shareholders through further debt reduction, within our previously announced timeline.
# 📊 Extracted Result:
# Company Name: Jacobs Solutions
# Ticker Symbol: J
# Filing Date: 2025-03-13
# Product Name: 1 Jacobs
# Product Description: Jacobs Solutions offers a range of solutions and services, but in this instance, it seems they provided a 1 Jacobs chair as part of an investment.
# 💾 Saved: 1 Jacobs → extracted_data.csv
#
# 📄 Processing Johnson & Johnson (JNJ)
# [LOG] EX-99.1: Fallback
# [LOG] 🧠 0 candidate sentences found
# 📊 Extracted Result:
# Company Name: Johnson & Johnson
# Ticker Symbol: JNJ
# Filing Date: 2025-02-26
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing Johnson Controls (JCI)
# [LOG] EX-99.1: Fallback
# [LOG] No usable text
#
# 📄 Processing JPMorgan Chase (JPM)
# [LOG] EX-99.1: Fallback
# [LOG] 🧠 0 candidate sentences found
# 📊 Extracted Result:
# Company Name: JPMorgan Chase
# Ticker Symbol: JPM
# Filing Date: 2025-02-04
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing Juniper Networks (JNPR)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/1043604/000104360425000004/jnpr-20241231ex991.htm
# [LOG] 🧠 5 candidate sentences found
# [LOG] [CANDIDATE] Proposed Merger with Hewlett Packard Enterprise As announced on January 9, 2024, Hewlett Packard Enterprise Company (“HPE”) plans to acquire Juniper Networks in an all-cash transaction for $40.00 per share, representing an equity value of approximately $14 billion.
# 📊 Extracted Result:
# Company Name: Juniper Networks
# Ticker Symbol: JNPR
# Filing Date: 2025-02-04
# Product Name: Proposed
# Product Description: Juniper Networks proposes a proposed merger with HPE to combine their product offerings and capabilities into a single, more extensive network platform.
# 💾 Saved: Proposed → extracted_data.csv
#
# 📄 Processing Kellanova (K)
# [LOG] EX-99.1: Fallback
# [LOG] 🧠 1 candidate sentences found
# [LOG] [CANDIDATE] Any Lien created for the benefit of the Holders pursuant to
# Section 3.6(a) shall provide by its terms that such Lien shall be automatically and unconditionally released and discharged upon the release and discharge of the Lien that gave rise to such Lien created for the benefit of the
# Holders.
# 📊 Extracted Result:
# Company Name: Kellanova
# Ticker Symbol: K
# Filing Date: 2025-03-12
# Product Name: N/A
# Product Description: N/A
# [LOG] Skipping invalid product.
#
# 📄 Processing Kenvue (KVUE)
# [LOG] EX-99.1: https://www.sec.gov/Archives/edgar/data/1944048/000194404825000035/exhibit991-pressrelease.htm
# [LOG] 🧠 2 candidate sentences found
# [LOG] [CANDIDATE] The director appointments announced today are being made in connection with a cooperation agreement entered into between the Company and Starboard.
# [LOG] [CANDIDATE] With these appointments, the Board will temporarily expand from 11 to 14 directors, and as of the 2025 Annual Meeting of Shareholders, the Board will be reduced to 13 directors.
